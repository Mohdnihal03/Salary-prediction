# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("global_ai_ml_data_salaries.csv")
df.head()
# Out:
#    work_year experience_level employment_type          job_title  salary  \
# 0       2024               SE              FT  Research Engineer  284900
# 1       2024               SE              FT  Research Engineer  161700
# 2       2024               MI              FT  Research Engineer  138000
# 3       2024               MI              FT  Research Engineer   86000
# 4       2024               SE              FT  Research Engineer  179000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         284900                 US             0
# 1             USD         161700                 US             0
# 2             USD         138000                 US             0
# 3             USD          86000                 US             0
# 4             USD         179000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            M
# 4               US            M

# %%
df.shape
# Out:
# (20565, 11)

# %%
df.sample(10)
# Out:
#        work_year experience_level employment_type                  job_title  \
# 17643       2023               SE              FT             Data Scientist
# 15065       2023               MI              FT              Data Engineer
# 4697        2024               MI              FT              Data Engineer
# 6274        2024               SE              FT             Data Architect
# 15449       2023               SE              FT             Data Scientist
# 11733       2023               SE              FT  Machine Learning Engineer
# 13328       2023               SE              FT  Machine Learning Engineer
# 14829       2023               SE              FT             Data Scientist
# 19552       2022               SE              FT              Data Engineer
# 4311        2024               MI              FT               Data Analyst
#
#        salary salary_currency  salary_in_usd  remote_ratio company_location  \
# 17643  239748             USD         239748             0               US
# 15065  180000             USD         180000           100               US
# 4697    64300             USD          64300             0               US
# 6274    92190             USD          92190             0               CA
# 15449  136000             USD         136000           100               US
# 11733  207700             USD         207700             0               CA
# 13328  150000             USD         150000           100               US
# 14829   75000             GBP          92280           100               GB
# 19552  229998             USD         229998             0               US
# 4311   125000             USD         125000           100               US
#
#       company_size
# 17643            M
# 15065            M
# 4697             M
# 6274             M
# 15449            M
# 11733            M
# 13328            M
# 14829            M
# 19552            L
# 4311             M

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20565 entries, 0 to 20564
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           20565 non-null  int64
#  1   experience_level    20565 non-null  object
#  2   employment_type     20565 non-null  object
#  3   job_title           20565 non-null  object
#  4   salary              20565 non-null  int64
#  5   salary_currency     20565 non-null  object
#  6   salary_in_usd       20565 non-null  int64
#  7   employee_residence  20565 non-null  object
#  8   remote_ratio        20565 non-null  int64
#  9   company_location    20565 non-null  object
#  10  company_size        20565 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.7+ MB

# %%
df.drop(['employee_residence'],axis=1,inplace=True)

# %%
numerical_features = ['work_year', 'salary', 'salary_in_usd', 'remote_ratio']
correlation_matrix = df[numerical_features].corr()

# Step 3: Plot the heatmap for the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
print("Correlation values with salary_in_usd:")
print(correlation_matrix['salary_in_usd'].sort_values(ascending=False))
# Out:
# Correlation values with salary_in_usd:
# salary_in_usd    1.000000
# salary           0.165017
# work_year        0.080293
# remote_ratio    -0.065724
# Name: salary_in_usd, dtype: float64
